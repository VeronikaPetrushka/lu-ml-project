# %%
import pandas as pd

# %%
data = pd.read_csv('WorldHappiness.csv').dropna()

# %% [markdown]
# America

# %%
america = [
    'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada',
    'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'El Salvador',
    'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
    'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia',
    'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'United States', 'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador',
    'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'
]

# Filter rows based on the specified column values
american_data = data[data['Country name'].isin(
    america)]

# Display the filtered data
print(american_data)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 46      Argentina  2006        6.313               9.937           0.938
# 47      Argentina  2007        6.073              10.013           0.862
# 48      Argentina  2008        5.961              10.043           0.892
# 49      Argentina  2009        6.424               9.972           0.919
# 50      Argentina  2010        6.441              10.066           0.927
# ...           ...   ...          ...                 ...             ...
# 2287    Venezuela  2015        5.569               8.532           0.911
# 2288    Venezuela  2016        4.041               7.602           0.902
# 2289    Venezuela  2017        5.071               5.943           0.896
# 2290    Venezuela  2018        5.006               5.935           0.887
# 2291    Venezuela  2019        5.081               5.527           0.888
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# South America data

# %%
south_america = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador',
                        'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela']

south_america_data = data[data['Country name'].isin(south_america)]

print(south_america_data)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 46      Argentina  2006        6.313               9.937           0.938
# 47      Argentina  2007        6.073              10.013           0.862
# 48      Argentina  2008        5.961              10.043           0.892
# 49      Argentina  2009        6.424               9.972           0.919
# 50      Argentina  2010        6.441              10.066           0.927
# ...           ...   ...          ...                 ...             ...
# 2287    Venezuela  2015        5.569               8.532           0.911
# 2288    Venezuela  2016        4.041               7.602           0.902
# 2289    Venezuela  2017        5.071               5.943           0.896
# 2290    Venezuela  2018        5.006               5.935           0.887
# 2291    Venezuela  2019        5.081               5.527           0.888
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# North America data

# %%
north_america = [
    'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada',
    'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'El Salvador',
    'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico',
    'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia',
    'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'United States'
]

# Filter rows based on the specified column values
north_america_data = data[data['Country name'].isin(
    north_america)]

# Display the filtered data
print(north_america_data)
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 191          Belize  2007        6.451               9.192           0.872
# 192          Belize  2014        5.956               9.135           0.757
# 349          Canada  2005        7.418              10.707           0.962
# 351          Canada  2008        7.486              10.733           0.939
# 352          Canada  2009        7.488              10.692           0.943
# ...             ...   ...          ...                 ...             ...
# 2238  United States  2019        6.944              11.042           0.917
# 2239  United States  2020        7.028              11.005           0.937
# 2240  United States  2021        6.959              11.061           0.920
# 2241  United States  2022        6.693              11.078           0.900
# 2242  United States  2023        6.521              11.089           0.861
#
# ...

# %% [markdown]
# European data

# %%
europe = [
    'Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium',
    'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic',
    'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
    'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kosovo', 'Latvia',
    'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova',
    'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway',
    'Poland', 'Portugal', 'Romania', 'San Marino', 'Serbia', 'Slovakia',
    'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine',
    'United Kingdom', 'Vatican City'
]

european_data = data[data['Country name'].isin(europe)]

print(european_data)
# Out:
#         Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 15           Albania  2007        4.634               9.122           0.821
# 16           Albania  2009        5.485               9.241           0.833
# 17           Albania  2010        5.269               9.283           0.733
# 18           Albania  2011        5.867               9.310           0.759
# 19           Albania  2012        5.510               9.326           0.785
# ...              ...   ...          ...                 ...             ...
# 2220  United Kingdom  2019        7.157              10.760           0.943
# 2221  United Kingdom  2020        6.798              10.639           0.929
# 2222  United Kingdom  2021        6.867              10.713           0.854
# 2223  United Kingdom  2022        6.722              10.754           0.863
# 2224  United Kingdom  2023        6.658              10.759           0.886
#
# ...

# %% [markdown]
# Asian data

# %%
asia = [
    'Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan',
    'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'India', 'Indonesia',
    'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait',
    'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia',
    'Myanmar (Burma)', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Philippines',
    'Qatar', 'Russia', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka',
    'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey',
    'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'
]

asian_data = data[data['Country name'].isin(asia)]

print("\nAsian Data:")
print(asian_data)
# Out:
# Asian Data:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2319        Yemen  2013        4.218               8.166           0.694
# 2320        Yemen  2014        3.968               8.159           0.638
# 2321        Yemen  2015        2.983               7.772           0.669
# 2324        Yemen  2018        3.058               7.444           0.789
# 2325        Yemen  2019        4.197               7.448           0.870
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# African data

# %%
africa = [
    'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi',
    'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)',
    'Congo (Kinshasa)', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea',
    'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau',
    'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi',
    'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger',
    'Nigeria', 'Rwanda', 'São Tomé and Príncipe', 'Senegal', 'Seychelles',
    'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania',
    'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'
]

african_data = data[data['Country name'].isin(africa)]

print("African Data:")
print(african_data)
# Out:
# African Data:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 32        Algeria  2011        5.317               9.316           0.810
# 33        Algeria  2012        5.605               9.330           0.839
# 36        Algeria  2017        5.249               9.377           0.807
# 37        Algeria  2018        5.043               9.370           0.799
# 38        Algeria  2019        4.745               9.361           0.803
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019        2.694               7.698           0.759
# 2359     Zimbabwe  2020        3.160               7.596           0.717
# 2360     Zimbabwe  2021        3.155               7.657           0.685
# 2361     Zimbabwe  2022        3.296               7.670           0.666
# 2362     Zimbabwe  2023        3.572               7.679           0.694
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# Oceanian data

# %%
oceania = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia',
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa',
    'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu'
]

oceanian_data = data[data['Country name'].isin(oceania)]

print("Oceanian Data:")
print(oceanian_data)
# Out:
# Oceanian Data:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 82      Australia  2007        7.285              10.694           0.965
# 83      Australia  2008        7.254              10.709           0.947
# 84      Australia  2010        7.450              10.714           0.955
# 85      Australia  2011        7.406              10.723           0.967
# 86      Australia  2012        7.196              10.744           0.945
# 87      Australia  2013        7.364              10.752           0.928
# 88      Australia  2014        7.289              10.763           0.924
# 89      Australia  2015        7.309              10.770           0.952
# 90      Australia  2016        7.250              10.781           0.942
# 91      Australia  2017        7.257              10.787           0.950
# 92      Australia  2018        7.177              10.801           0.940
# 93      Australia  2019        7.234              10.807           0.943
# ...

# %%
# %store american_data
# %store south_america_data
# %store north_america_data
# %store european_data
# %store asian_data
# %store african_data
# %store oceanian_data
# Out:
# Stored 'american_data' (DataFrame)
# Stored 'south_america_data' (DataFrame)
# Stored 'north_america_data' (DataFrame)
# Stored 'european_data' (DataFrame)
# Stored 'asian_data' (DataFrame)
# Stored 'african_data' (DataFrame)
# Stored 'oceanian_data' (DataFrame)
